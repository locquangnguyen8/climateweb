# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd

df = pd.read_excel('Projected_impacts_datasheet_11.24.2021.xlsx', sheet_name=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/compat/_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1142, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
df.head()
# Out:
#    ID Ref No   Future_Mid-point  Baseline_Mid-point Time slice  \
# 0   2       1              2054                1995         MC
# 1   4       2              2055                1998         MC
# 2  14       5              2070                2002         EC
# 3  15       5              2070                2002         EC
# 4  16       5              2070                2002         EC
#
#   Climate scenario Scenario source            Method     Scale   Crop  ...  \
# 0           RCP8.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
# 1           RCP8.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
# 2           RCP4.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
# 3           RCP4.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
# 4           RCP4.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
#
#      CO2 ppm Impact relative to 2005_NAD_% Impact relative to 2005_NAD_yield  \
# ...

# %%
df.shape
# Out:
# (2005, 42)

# %%
df.describe()
# Out:
#                 ID  Future_Mid-point  Baseline_Mid-point     latitude  \
# count  2005.000000       2005.000000         2005.000000  2004.000000
# mean   4801.131671       2056.022444         1994.990025    26.506349
# std    2722.004729         20.313069           12.093692    20.971099
# min       2.000000       2020.000000         1975.000000   -38.416100
# 25%    1110.000000       2050.000000         1990.000000    19.856300
# 50%    5401.000000       2050.000000         2000.000000    32.760000
# 75%    7009.000000       2080.000000         2005.000000    38.963700
# max    8685.000000       2100.000000         2012.000000    61.524000
#
#          longitude  Current Average Temperature (dC)_area_weighted  \
# count  2004.000000                                     2004.000000
# mean     25.973802                                       18.220760
# std      72.243844                                        6.708541
# ...

# %%
from matplotlib import pyplot as plt
_df_11['latitude'].plot(kind='line', figsize=(8, 4), title='latitude')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3['latitude'].plot(kind='hist', bins=20, title='latitude')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.isnull().sum()
# Out:
# ID                                                         0
# Ref No                                                     0
# Future_Mid-point                                           0
# Baseline_Mid-point                                         0
# Time slice                                                 0
# Climate scenario                                           0
# Scenario source                                            0
# Method                                                     0
# Scale                                                      0
# Crop                                                       0
# Country                                                    0
# Site(location)                                          1164
# Region                                                     0
# latitude                                                   1
# longitude                                                  1
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
print(len(col_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ba387e4bd69f> in <cell line: 1>()
# ----> 1 print(len(col_list))
#
# NameError: name 'col_list' is not defined

# %%
#print(df.columns.values.tolist())
col_list = df.columns.values.tolist()
for i in col_list:
  print(i)
# Out:
# ID
# Ref_No_
# Future_Mid-point
# Baseline_Mid-point
# Time_slice
# Climate_scenario
# Scenario_source
# Method
# Scale
# Crop
# Country
# Site(location)
# Region
# latitude
# longitude
# Current_Average_Temperature_(dC)_area_weighted
# Current_Average_Temperature_point_coordinate_(dC)
# Current_Annual_Precipitation_(mm)__area_weighted_
# Current_Annual_Precipitation__(mm)__point_coordinate
# Local_delta_T_from_2005
# Global_delta_T_from_pre-industrial_period_
# Global_delta_T_from_2005
# _Annual_Precipitation_change__from_2005_(mm)
# Fertiliser
# Irrigation
# Cultivar
# Soil_organic_matter_management
# Planting_time
# Tillage
# Others_
# Adaptation_type
# CO2
# CO2_ppm
# Impact_relative_to_2005_NAD_%
# Impact_relative_to_2005_NAD_yield
# Impact_relative_to_2005_AD_%
# Impact_relative_to_2005_AD_yield
# Adaptation_potential_(%)
# Adaptation_potential_actual_yield
# Reference
# doi
# Publication_year

# %%
# Dictionary with new column names
new_column_names = {
    'Ref_No_': 'Ref_No',
    'Current_Annual_Precipitation_(mm)__area_weighted_': 'Current_Annual_Precipitation_(mm)__area_weighted',
    'Global_delta_T_from_pre-industrial_period_': 'Global_delta_T_from_pre-industrial_period',
    '_Annual_Precipitation_change__from_2005_(mm)': 'Annual_Precipitation_change__from_2005_(mm)',
    'Others_': 'Others'
}

# Rename columns
df.rename(columns=new_column_names, inplace=True)

# %%
# Assuming df is a DataFrame in Python
# If not, you can read your data into a DataFrame using pd.read_csv, pd.read_excel, etc.

# Extraction of columns
Species = pd.Categorical(df["Crop"])
Ref = df["Ref_No"]
ID = range(1, len(df) + 1)
Pr_change = pd.to_numeric(df["Annual_Precipitation_change__from_2005_(mm)"], errors='coerce')
Pr_avg = pd.to_numeric(df["Current_Annual_Precipitation_(mm)__area_weighted"], errors='coerce')
Effect = pd.to_numeric(df["Impact_relative_to_2005_NAD_%"], errors='coerce')
CO2_ppm = df["CO2_ppm"]
RCP = pd.Categorical(df["Climate_scenario"])
TempAvg = pd.to_numeric(df["Current_Average_Temperature_(dC)_area_weighted"], errors='coerce')
latitude = df["latitude"]
longitude = df["longitude"]
Futureyear = df["Future_Mid-point"]

# %%
# prompt: write code to check each column for missing values and NA and NaNs and replace them with mean for numerical column and mode with categorical cilumns

import numpy as np

# Check for missing values in each column
missing_values = df.isnull().sum()

# Replace missing values in numerical columns with the mean
numerical_columns = df.select_dtypes(include=[np.number])
df[numerical_columns.columns] = numerical_columns.fillna(numerical_columns.mean())

# Replace missing values in categorical columns with the mode
categorical_columns = df.select_dtypes(exclude=[np.number])
df[categorical_columns.columns] = categorical_columns.fillna(categorical_columns.mode().iloc[0])

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# ID                                                      0
# Ref_No                                                  0
# Future_Mid-point                                        0
# Baseline_Mid-point                                      0
# Time_slice                                              0
# Climate_scenario                                        0
# Scenario_source                                         0
# Method                                                  0
# Scale                                                   0
# Crop                                                    0
# Country                                                 0
# Site(location)                                          0
# Region                                                  0
# latitude                                                0
# longitude                                               0
# Current_Average_Temperature_(dC)_area_weighted          0
# ...

# %%
df.head()
# Out:
#    ID Ref_No  Future_Mid-point  Baseline_Mid-point Time_slice  \
# 0   2      1              2054                1995         MC
# 1   4      2              2055                1998         MC
# 2  14      5              2070                2002         EC
# 3  15      5              2070                2002         EC
# 4  16      5              2070                2002         EC
#
#   Climate_scenario Scenario_source            Method     Scale   Crop  ...  \
# 0           RCP8.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
# 1           RCP8.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
# 2           RCP4.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
# 3           RCP4.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
# 4           RCP4.5           CMIP5  SCOPUS-NewSearch  Regional  Maize  ...
#
#      CO2_ppm Impact_relative_to_2005_NAD_% Impact_relative_to_2005_NAD_yield  \
# ...

# %%
# prompt: code to view entire dataframe without compressing columns

pd.set_option('display.max_columns', None)
print(df)
# Out:
#         ID  Future_Mid-point  Baseline_Mid-point Time_slice Climate_scenario  \
# 0        2              2054                1995         MC           RCP8.5
# 1        4              2055                1998         MC           RCP8.5
# 2       14              2070                2002         EC           RCP4.5
# 3       15              2070                2002         EC           RCP4.5
# 4       16              2070                2002         EC           RCP4.5
# ...    ...               ...                 ...        ...              ...
# 2000  8681              2085                1975         EC           Others
# 2001  8682              2085                1975         EC           Others
# 2002  8683              2085                1975         EC           Others
# 2003  8684              2085                1975         EC           Others
# 2004  8685              2085                1975         EC           Others
#
# ...

# %%
df.drop(columns=['Reference', 'Publication_year', 'Ref_No', 'Method', 'Scenario_source', 'doi', 'ID'], inplace=True)

# %%
# prompt: code to show the correlation matrix graph against Local_delta_T_from_2005

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
corr = df.corr()

# Select the columns you want to analyze
selected_cols = ['Local_delta_T_from_2005', 'Annual_Precipitation_change__from_2005_(mm)', 'Current_Annual_Precipitation_(mm)__area_weighted', 'Current_Average_Temperature_(dC)_area_weighted', 'Impact_relative_to_2005_NAD_%']

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr[selected_cols], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Selected Columns against Local_delta_T_from_2005')
plt.show()
# Out:
# <ipython-input-35-31f587e9c3bb>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
# prompt: code to show all the numerical colums and save it to new variable

numerical_columns = df.select_dtypes(include=[np.number])
numerical_data = numerical_columns.copy()

# %%
df.shape
# Out:
# (2005, 35)

# %%
numerical_data.shape
# Out:
# (2005, 19)

# %%
# prompt: apply famd

from sklearn.decomposition import FactorAnalysis

# Create a FactorAnalysis object with 10 factors
fa = FactorAnalysis(n_components=10, random_state=123)

# Fit the model to the numerical data
fa.fit(numerical_data)

# Extract the transformed data
transformed_data = fa.transform(numerical_data)

# Print the shape of the transformed data
print(transformed_data.shape)
# Out:
# (2005, 10)

# %%
transformed_data
# Out:
# array([[-0.51352668, -1.64288511, -0.87023832, ..., -0.66729873,
#         -0.14149773,  0.57139603],
#        [-0.67873905, -2.82036275, -0.85114442, ..., -0.71385608,
#         -0.64135788, -0.28896619],
#        [ 0.25511834, -0.18652064,  0.22116281, ...,  0.41291505,
#         -0.22123382, -1.16538814],
#        ...,
#        [ 0.08048787, -1.13909045,  0.26882864, ...,  2.27532929,
#          2.39007219,  0.30152263],
#        [-0.18570317, -1.4802298 ,  0.26839847, ...,  2.22735578,
#          2.35136767,  0.41808487],
#        [-0.66692156, -3.00347816, -1.1700259 , ...,  2.60228413,
#          1.75444399,  0.88475019]])

# %%
# prompt: apply dimentionality reduction to reduce the columns, there is categorical values as well

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Standardize the numerical data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_data)

# Apply PCA
pca = PCA(n_components=0.95)
pca_data = pca.fit_transform(scaled_data)

# Convert the PCA data back to a DataFrame
pca_df = pd.DataFrame(pca_data)

# Combine the PCA data with the categorical data
combined_data = pd.concat([pca_df, df[['Crop', 'Climate_scenario']]], axis=1)

# Print the shape of the combined data
print(combined_data.shape)

# %%
DATA2 = df[['Local_delta_T_from_2005', 'Global_delta_T_from_2005', 'Climate_scenario', 'Future_Mid-point_']]
DATA3 = df[['Local_delta_T_from_2005', 'Global_delta_T_from_2005', 'longitude', 'latitude', 'Climate_scenario', 'Future_Mid-point_']]

# %%
df.Adaptation.head()

# %%
#######################
#Method: random forest#
#######################
##Local Temperature delta Prediction
# Cross validation

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer

# Assuming df is your DataFrame
# Replace df with your actual DataFrame name

# Data Preparation
DATA = df[['Local_delta_T_from_2005', 'Global_delta_T_from_2005', 'latitude', 'longitude', 'Climate_scenario', 'Future_Mid-point', 'Current_Average_Temperature_(dC)_area_weighted', 'Current_Average_Temperature_(dC)_area_weighted', 'Country', 'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar', 'Adaptation_type']]
DATA2 = df[['Local_delta_T_from_2005', 'Global_delta_T_from_2005', 'latitude', 'longitude', 'Climate_scenario', 'Future_Mid-point', 'Current_Average_Temperature_(dC)_area_weighted', 'Current_Average_Temperature_(dC)_area_weighted', 'Country', 'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar', 'Adaptation_type']]
DATA3 = df[['Local_delta_T_from_2005', 'Global_delta_T_from_2005', 'latitude', 'longitude', 'Climate_scenario', 'Future_Mid-point', 'Current_Average_Temperature_(dC)_area_weighted', 'Current_Average_Temperature_(dC)_area_weighted', 'Country', 'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar', 'Adaptation_type']]
DATA4 = df[['Local_delta_T_from_2005', 'Global_delta_T_from_2005', 'latitude', 'longitude', 'Climate_scenario', 'Future_Mid-point', 'Current_Average_Temperature_(dC)_area_weighted', 'Current_Average_Temperature_(dC)_area_weighted', 'Country', 'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar', 'Adaptation_type']]

# %%
# prompt: apply one hot encoder to Climate_scenario on DATA2, DATA3

from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder object
encoder = OneHotEncoder()

# Fit the encoder to the Climate_scenario column in DATA2
encoder.fit(DATA2[['Climate_scenario']])

# Transform the Climate_scenario column in DATA2
DATA2 = encoder.transform(DATA2[['Climate_scenario']])

# Fit the encoder to the Climate_scenario column in DATA3
encoder.fit(DATA3[['Climate_scenario']])

# Transform the Climate_scenario column in DATA3
DATA3 = encoder.transform(DATA3[['Climate_scenario']])

# %%
DATA.shape
# Out:
# (2005, 14)

# %%
#apply label encoder to all cateogrical and boolena columns in DATA, DATA2, DATA3, DATA4

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Encode the categorical and boolean columns in DATA
for column in ['Country', 'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar', 'Adaptation_type']:
    DATA[column] = label_encoder.fit_transform(DATA[column])

# Encode the categorical and boolean columns in DATA2
for column in ['Country', 'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar', 'Adaptation_type']:
    DATA2[column] = label_encoder.fit_transform(DATA2[column])

# Encode the categorical and boolean columns in DATA3
for column in ['Country', 'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar', 'Adaptation_type']:
    DATA3[column] = label_encoder.fit_transform(DATA3[column])

# Encode the categorical and boolean columns in DATA4
for column in ['Country', 'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar', 'Adaptation_type']:
    DATA4[column] = label_encoder.fit_transform(DATA4[column])
# Out:
# <ipython-input-16-b3a3004d028f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA[column] = label_encoder.fit_transform(DATA[column])
# <ipython-input-16-b3a3004d028f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA[column] = label_encoder.fit_transform(DATA[column])
# <ipython-input-16-b3a3004d028f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# prompt: convert object to numerical, Climate_scernario on DATA2, and DATA3

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
DATA['Climate_scenario'] = le.fit_transform(DATA2['Climate_scenario'])
DATA3['Climate_scenario'] = le.fit_transform(DATA3['Climate_scenario'])
DATA2['Climate_scenario'] = le.fit_transform(DATA2['Climate_scenario'])
DATA4['Climate_scenario'] = le.fit_transform(DATA3['Climate_scenario'])
# Out:
# <ipython-input-18-4c03e13e57d1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA['Climate_scenario'] = le.fit_transform(DATA2['Climate_scenario'])
# <ipython-input-18-4c03e13e57d1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA3['Climate_scenario'] = le.fit_transform(DATA3['Climate_scenario'])
# <ipython-input-18-4c03e13e57d1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# prompt: show data types on DATA

print(DATA2.dtypes)
# Climate_scenario needs, has 10 unique values
# Out:
# Local_delta_T_from_2005                           float64
# Global_delta_T_from_2005                          float64
# latitude                                          float64
# longitude                                         float64
# Climate_scenario                                    int64
# Future_Mid-point                                    int64
# Current_Average_Temperature_(dC)_area_weighted    float64
# Current_Average_Temperature_(dC)_area_weighted    float64
# Country                                             int64
# Time_slice                                          int64
# Fertiliser                                          int64
# Irrigation                                          int64
# Cultivar                                            int64
# Adaptation_type                                     int64
# dtype: object

# %%
print(DATA3.dtypes)
# Climate_scenario needs, has 10 unique values
# Out:
# Local_delta_T_from_2005                           float64
# Global_delta_T_from_2005                          float64
# latitude                                          float64
# longitude                                         float64
# Climate_scenario                                   object
# Future_Mid-point                                    int64
# Current_Average_Temperature_(dC)_area_weighted    float64
# Current_Average_Temperature_(dC)_area_weighted    float64
# Country                                             int64
# Time_slice                                          int64
# Climate_scenario                                   object
# Fertiliser                                          int64
# Irrigation                                          int64
# Cultivar                                            int64
# Adaptation_type                                     int64
# dtype: object

# %%
DATA2.Climate_scenario.unique()
# Out:
# array([9, 7, 8, 6, 2, 4, 5, 0, 3, 1])

# %%
DATA_train = DATA
DATA_train2 = DATA2
DATA_train3 = DATA3
DATA_train4 = DATA4

# %%
# Random Forest Modeling
X_train = DATA_train.drop('Local_delta_T_from_2005', axis=1)
y_train = DATA_train['Local_delta_T_from_2005']

X_train2 = DATA_train2.drop('Local_delta_T_from_2005', axis=1)
y_train2 = DATA_train2['Local_delta_T_from_2005']

X_train3 = DATA_train3.drop('Local_delta_T_from_2005', axis=1)
y_train3 = DATA_train3['Local_delta_T_from_2005']

X_train4 = DATA_train4.drop('Local_delta_T_from_2005', axis=1)
y_train4 = DATA_train4['Local_delta_T_from_2005']

# %%
"""
Models with mode columns
"""
# Create Random Forest Models
mod_rf = RandomForestRegressor(n_estimators=500, random_state=42)
mod_rf.fit(X_train, y_train)

mod_rf2 = RandomForestRegressor(n_estimators=500, random_state=42)
mod_rf2.fit(X_train2, y_train2)

mod_rf3 = RandomForestRegressor(n_estimators=500, random_state=42)
mod_rf3.fit(X_train3, y_train3)

mod_rf4 = RandomForestRegressor(n_estimators=500, random_state=42)
mod_rf4.fit(X_train4, y_train4)
# Out:
# RandomForestRegressor(n_estimators=500, random_state=42)

# %%
# Create Random Forest Models
mod_rf = RandomForestRegressor(n_estimators=500, random_state=42)
mod_rf.fit(X_train, y_train)

mod_rf2 = RandomForestRegressor(n_estimators=500, random_state=42)
mod_rf2.fit(X_train2, y_train2)

mod_rf3 = RandomForestRegressor(n_estimators=500, random_state=42)
mod_rf3.fit(X_train3, y_train3)

mod_rf4 = RandomForestRegressor(n_estimators=500, random_state=42)
mod_rf4.fit(X_train4, y_train4)
# Out:
# RandomForestRegressor(n_estimators=500, random_state=42)

# %%
print("Features in DATA_train:", DATA_train.columns)

# Print the names of the features used to fit the model
# (This code is not provided in the original user input)
# print("Features used for model fitting:", mod_rf.feature_names_in_)
# Out:
# Features in DATA_train: Index(['Local_delta_T_from_2005', 'Global_delta_T_from_2005', 'latitude',
#        'longitude', 'Climate_scenario', 'Future_Mid-point',
#        'Current_Average_Temperature_(dC)_area_weighted',
#        'Current_Average_Temperature_(dC)_area_weighted', 'Country',
#        'Time_slice', 'Fertiliser', 'Irrigation', 'Cultivar',
#        'Adaptation_type'],
#       dtype='object')

# %%
print("Features used for model fitting:", mod_rf.feature_names_in_)
# Out:
# Features used for model fitting: ['Global_delta_T_from_2005' 'latitude' 'longitude' 'Climate_scenario'
#  'Future_Mid-point' 'Current_Average_Temperature_(dC)_area_weighted'
#  'Current_Average_Temperature_(dC)_area_weighted' 'Country' 'Time_slice'
#  'Fertiliser' 'Irrigation' 'Cultivar' 'Adaptation_type']

# %%
"""
CV for bigger dataset
"""

# Cross-validation
y_pred_cv = mod_rf.predict(DATA_train.iloc[:, 1:])
mse_cv = mean_squared_error(y_train, y_pred_cv)
print("Cross-validation MSE for mod_rf:", mse_cv)

y_pred_cv2 = mod_rf2.predict(DATA_train2.iloc[:, 1:])
mse_cv2 = mean_squared_error(y_train2, y_pred_cv2)
print("Cross-validation MSE for mod_rf2:", mse_cv2)

y_pred_cv3 = mod_rf3.predict(DATA_train3.iloc[:, 1:])
mse_cv3 = mean_squared_error(y_train3, y_pred_cv3)
print("Cross-validation MSE for mod_rf3:", mse_cv3)

y_pred_cv4 = mod_rf4.predict(DATA_train4.iloc[:, 1:])
mse_cv4 = mean_squared_error(y_train4, y_pred_cv4)
print("Cross-validation MSE for mod_rf4:", mse_cv4)

# Feature Importance
importances_rf = mod_rf.feature_importances_
print("Feature Importance for mod_rf:", importances_rf)

importances_rf2 = mod_rf2.feature_importances_
print("Feature Importance for mod_rf2:", importances_rf2)

importances_rf3 = mod_rf3.feature_importances_
print("Feature Importance for mod_rf3:", importances_rf3)

importances_rf4 = mod_rf4.feature_importances_
print("Feature Importance for mod_rf4:", importances_rf4)
# Out:
# Cross-validation MSE for mod_rf: 0.004607168318592218
# Cross-validation MSE for mod_rf2: 0.004607168318592218
# Cross-validation MSE for mod_rf3: 0.004607168318592218
# Cross-validation MSE for mod_rf4: 0.004607168318592218
# Feature Importance for mod_rf: [8.19789061e-01 3.81059637e-02 3.06389982e-02 2.26831862e-02
#  9.71946684e-03 1.60229071e-02 1.52548080e-02 8.82099991e-03
#  2.08809678e-02 1.19413582e-03 2.97924082e-04 1.35416821e-03
#  1.52374131e-02]
# Feature Importance for mod_rf2: [8.19789061e-01 3.81059637e-02 3.06389982e-02 2.26831862e-02
#  9.71946684e-03 1.60229071e-02 1.52548080e-02 8.82099991e-03
#  2.08809678e-02 1.19413582e-03 2.97924082e-04 1.35416821e-03
#  1.52374131e-02]
# Feature Importance for mod_rf3: [8.19789061e-01 3.81059637e-02 3.06389982e-02 2.26831862e-02
#  9.71946684e-03 1.60229071e-02 1.52548080e-02 8.82099991e-03
#  2.08809678e-02 1.19413582e-03 2.97924082e-04 1.35416821e-03
#  1.52374131e-02]
# ...

# %%
# Cross-validation
y_pred_cv = mod_rf.predict(DATA_train.iloc[:, 1:4])
mse_cv = mean_squared_error(y_train, y_pred_cv)
print("Cross-validation MSE for mod_rf:", mse_cv)

y_pred_cv2 = mod_rf2.predict(DATA_train2.iloc[:, 1:4])
mse_cv2 = mean_squared_error(y_train2, y_pred_cv2)
print("Cross-validation MSE for mod_rf2:", mse_cv2)

y_pred_cv3 = mod_rf3.predict(DATA_train3.iloc[:, 1:6])
mse_cv3 = mean_squared_error(y_train3, y_pred_cv3)
print("Cross-validation MSE for mod_rf3:", mse_cv3)

y_pred_cv4 = mod_rf4.predict(DATA_train4.iloc[:, 1:5])
mse_cv4 = mean_squared_error(y_train4, y_pred_cv4)
print("Cross-validation MSE for mod_rf4:", mse_cv4)

# Feature Importance
importances_rf = mod_rf.feature_importances_
print("Feature Importance for mod_rf:", importances_rf)

importances_rf2 = mod_rf2.feature_importances_
print("Feature Importance for mod_rf2:", importances_rf2)

importances_rf3 = mod_rf3.feature_importances_
print("Feature Importance for mod_rf3:", importances_rf3)

importances_rf4 = mod_rf4.feature_importances_
print("Feature Importance for mod_rf4:", importances_rf4)
# Out:
# Cross-validation MSE for mod_rf: 0.0057273342812639615
# Cross-validation MSE for mod_rf2: 0.08124618488552687
# Cross-validation MSE for mod_rf3: 0.00522181643314666
# Cross-validation MSE for mod_rf4: 0.0047275453464997634
# Feature Importance for mod_rf: [0.86488758 0.07591861 0.05919381]
# Feature Importance for mod_rf2: [0.91711859 0.03768324 0.04519817]
# Feature Importance for mod_rf3: [0.82969023 0.04399446 0.06278672 0.02870499 0.0348236 ]
# Feature Importance for mod_rf4: [0.85968966 0.04828442 0.05876205 0.03326387]

# %%
# prompt: save the label encoder

import pickle

# Save the label encoder
with open('label_encoder.pkl', 'wb') as f:
  pickle.dump(le, f)

# %%
# !mkdir encoder
! mv label_encoder.pkl
# Out:
# mkdir: cannot create directory ‘encoder’: File exists
# mv: missing destination file operand after 'label_encoder.pkl'
# Try 'mv --help' for more information.

# %%
#save the trained model mod_rf

# !mkdir model
# !mv mod_rf.pkl
# Out:
# mkdir: cannot create directory ‘model’: File exists
# mv: missing destination file operand after 'mod_rf.pkl'
# Try 'mv --help' for more information.

# %%
# Import necessary modules
import pickle

# Define the model name
model_name = "mod_rf.pkl"

# Open a file in binary write mode
with open(model_name, "wb") as f:
    # Use pickle.dump to save the model
    pickle.dump(mod_rf, f)

# Print confirmation message
print("Model saved as:", model_name)
# Out:
# Model saved as: mod_rf.pkl

# %%
#code to show location of code saved to

# !ls -l mod_rf.pkl
# Out:
# -rw-r--r-- 1 root root 57658241 Feb 14 15:26 mod_rf.pkl
